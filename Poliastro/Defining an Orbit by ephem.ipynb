# %%
from poliastro.examples import iss

# %%
from poliastro.twobody.orbit import Orbit

# %%
type(iss)
# Out:
# poliastro.twobody.orbit.Orbit

# %%
print(iss)
# Out:
# 6772 x 6790 km x 51.6 deg orbit around Earth (♁)

# %%
from poliastro.plotting import OrbitPlotter

# %%
iss_plot = OrbitPlotter()
iss_plot.plot(iss)

# %%
from poliastro.plotting import OrbitPlotter3D

# %%
iss_3D = OrbitPlotter3D()
iss_3D.plot(iss)
iss_3D.show()

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
iss_3D = OrbitPlotter3D()
iss_3D.plot(iss)
iss_3D.show()
# Out:
# <div id="2dd2e6f8-73df-4438-b6c8-6ff619423141" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2dd2e6f8-73df-4438-b6c8-6ff619423141", [{"type": "scatter3d", "x": [-4136.384037824359, -3804.534352677091, -3457.34337843634, -3096.2091306163074, -2722.5857693730222, -2337.9777441141364, -1943.93373561225, -1542.040420014407, -1133.9160798566238, -721.2040878119167, -305.5662894079817, 111.32368863767579, 527.7871775221981, 942.1472257641447, 1352.7353516949133, 1757.8982618460125, 2156.004508177761, 2545.4510573456837, 2924.6697455486574, 3292.133592972366, 3646.362952397253, 3985.931467215934, 4309.471814867819, 4615.68121256453, 4903.326663136131, 5171.249919875972, 5418.372150390914, 5643.698280678995, 5846.321001940904, 6025.424423992613, 6180.287360566936, 6310.286233276217, 6414.8975825423195, 6
# ...

# %% [markdown]
# Now, this was just an example

# %% [markdown]
# Let's define our own orbit

# %%
from poliastro.bodies import Earth, Mars

# %%
earth = Orbit.from_body_ephem(Earth)
mars = Orbit.from_body_ephem(Mars)

# %%
planets = OrbitPlotter()
planets.plot(earth,label='Earth')
planets.plot(mars,label='Mars')

# %%
planets3D = OrbitPlotter3D()
planets3D.plot(earth,label='Earth')
planets3D.plot(mars,label='Mars')
planets3D.show()
# Out:
# <div id="842f2d77-738b-475c-93c2-8499daee43ed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("842f2d77-738b-475c-93c2-8499daee43ed", [{"type": "scatter3d", "x": [-13963706.151419852, -23250300.279240374, -32441952.47173741, -41501651.18966804, -50392916.223859645, -59079945.588135734, -67527759.6812796, -75702342.13754138, -83570776.79853755, -91101380.25500345, -98263829.42469926, -105029283.65276045, -111370500.84283572, -117261947.1513935, -122679899.80349864, -127602542.61605364, -132010053.84386854, -135884685.99483246, -139210837.29280084, -141975114.5004411, -144166386.84907243, -145775830.8583429, -146796965.86527032, -147225680.1195851, -147060247.34029713, -146301333.66682017, -144951994.97666332, -143017664.58049136, -140506131.34409964, -137427508.32540116, -133794192.05271144, -129620
# ...

# %%
from poliastro.plotting import plot_solar_system

# %%
plot_solar_system(outer=True)

# %%
plot_solar_system(outer=False)
